# %%
import pandas as pd
import matplotlib.pyplot as plt
filepath="C:/Users/DELL/OneDrive/Desktop/IIT DHANBAD SAMRAT/7. Multivariate Lab/Practice/Exp 4 data.csv"
df = pd.read_csv(filepath)
df
# Out:
#     SL                                         Companies  V1  V2  V3  V4  V5  \
# 0    1                           3M India Ltd, Bangalore   3   3   1   1   4
# 1    2                   A C C Machinery Co. Ltd, Mumbai   1   1   3   3   2
# 2    3                        Ashok Leyland Ltd, Chennai   5   5   2   2   5
# 3    4                    Atlas Cycles, Sonepat, Haryana   4   4   4   1   4
# 4    5                           Audco India Ltd, Mumbai   1   1   3   3   2
# 5    6                      Automotive Axles Ltd, Mysore   5   5   2   2   4
# 6    7                         Avon Cycles Ltd, Ludhiana   3   3   5   2   3
# 7    8                     B S Refrigerators Ltd, Mumbai   2   2   5   3   4
# 8    9          Batliboi Environmental Engg. Ltd, Mumbai   2   2   3   3   2
# 9   10                Cable Corporation of India, Mumbai   4   4   1   1   5
# 10  11                                CMC Ltd, Hyderabad   3   3   1   1   4
# ...

# %%
y=df

# %%
df1=df.drop(['SL', 'Companies'], axis=1)

# %%
print(df1)
# Out:
#     V1  V2  V3  V4  V5  V6  V7  V8  V9  V10  V11  V12  V13  V14
# 0    3   3   1   1   4   4   2   5   5    1    1    1    1    1
# 1    1   1   3   3   2   1   1   1   1    1    5    5    4    4
# 2    5   5   2   2   5   4   4   1   1    3    3    3    3    3
# 3    4   4   4   1   4   3   5   3   1    4    5    4    4    2
# 4    1   1   3   3   2   1   1   1   1    1    5    4    4    4
# 5    5   5   2   2   4   4   4   2   1    3    2    3    3    3
# 6    3   3   5   2   3   1   5   2   1    3    4    3    3    3
# 7    2   2   5   3   4   4   4   1   2    4    4    4    3    5
# 8    2   2   3   3   2   2   2   1   1    1    4    4    4    4
# 9    4   4   1   1   5   5   5   5   1    3    1    3    3    4
# 10   3   3   1   1   4   4   3   5   5    1    1    2    2    2
# 11   4   4   1   1   4   3   3   4   5    1    1    2    2    2
# 12   5   5   2   1   4   3   3   1   1    2    3    3    3    3
# 13   3   3   1   1   4   4   4   5   4    1    1    1    1    1
# ...

# %%
dim=df.shape
print("Dimension of the data set is : ", dim)
# Out:
# Dimension of the data set is :  (41, 16)

# %%
df.head()
# Out:
#    SL                        Companies  V1  V2  V3  V4  V5  V6  V7  V8  V9  \
# 0   1          3M India Ltd, Bangalore   3   3   1   1   4   4   2   5   5
# 1   2  A C C Machinery Co. Ltd, Mumbai   1   1   3   3   2   1   1   1   1
# 2   3       Ashok Leyland Ltd, Chennai   5   5   2   2   5   4   4   1   1
# 3   4   Atlas Cycles, Sonepat, Haryana   4   4   4   1   4   3   5   3   1
# 4   5          Audco India Ltd, Mumbai   1   1   3   3   2   1   1   1   1
#
#    V10  V11  V12  V13  V14
# 0    1    1    1    1    1
# 1    1    5    5    4    4
# 2    3    3    3    3    3
# 3    4    5    4    4    2
# 4    1    5    4    4    4

# %%
from sklearn.cluster import AgglomerativeClustering as AC

# %%
agg = AC(n_clusters=10)

# %%
ypred = agg.fit_predict(df1)

# %%
x=agg.labels_
print(x)
# Out:
# [5 4 0 6 4 0 6 3 4 9 5 5 0 5 2 0 0 0 3 4 2 1 4 4 4 4 4 4 7 0 0 5 1 0 1 0 0
#  8 0 5 8]

# %%
from scipy.cluster.hierarchy import dendrogram, ward
result=ward(df1)
dendrogram(result)
plt.title("DENDROGRAM")
plt.xlabel('Observations')
plt.ylabel('Distances')
plt.show()
